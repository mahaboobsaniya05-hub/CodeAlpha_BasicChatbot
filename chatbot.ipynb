# %% [markdown]
# <a href="https://colab.research.google.com/github/mahaboobsaniya05-hub/CodeAlpha_BasicChatbot/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def chatbot():
    print("🤖 Simple Chatbot")
    print("Type 'bye' to end the chat.\n")

    while True:
        user = input("You: ").lower()

        if user == "hello":
            print("Bot: Hi! How can I help you?")

        elif user == "how are you":
            print("Bot: I'm fine, thanks! How about you?")

        elif user == "what is your name":
            print("Bot: I'm a simple Python chatbot.")

        elif user == "who created you":
            print("Bot: I was created using Python.")

        elif user == "thank you":
            print("Bot: You're welcome!")

        elif user == "bye":
            print("Bot: Goodbye! Have a nice day.")
            break

        else:
            print("Bot: Sorry, I don't understand that.")

# Start the chatbot
chatbot()
# Out:
# 🤖 Simple Chatbot
# Type 'bye' to end the chat.
#
# You: hello
# Bot: Hi! How can I help you?
# You: how are you
# Bot: I'm fine, thanks! How about you?
# You: who created you
# Bot: I was created using Python.
# You: thank you
# Bot: You're welcome!
# You: bye
# Bot: Goodbye! Have a nice day.
